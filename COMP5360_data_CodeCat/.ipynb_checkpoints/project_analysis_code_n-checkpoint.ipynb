# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
data = pd.read_csv('reduced_project_info.csv')
data.drop(index=0, inplace = True)
data
# Out:
#        Unnamed: 0      id                                 title        date  \
# 1               1       3               Analysis of the Obvious  2008-09-13
# 2               2       5             Dense Like Chocolate Cake  2008-09-13
# 3               3       6                            Dedication  2008-09-13
# 4               4       7                            Dedication  2008-09-13
# 5               5       8             His Place In the Universe  2008-09-13
# ...           ...     ...                                   ...         ...
# 99995       99995  118219                       Endless Road...  2006-08-19
# 99996       99996  118220                               Pain...  2006-11-18
# 99997       99997  118221   There, But for the Grace of Pt I...  2006-07-28
# 99998       99998  118222  There, But for the Grace of Pt II...  2006-10-02
# 99999       99999  118223                                   NaN         NaN
#
#        language  restricted  rating  finished   words     hits  kudos  \
# 1           1.0           0     1.0       1.0  2751.0   9643.0   43.0
# 2           1.0           0     1.0       1.0  4127.0  11831.0   24.0
# 3           1.0           0     2.0       1.0  5836.0  15812.0   25.0
# 4           1.0           0     2.0       1.0  5836.0   4803.0   51.0
# 5           1.0           0     0.0       1.0  1695.0  10520.0  202.0
# ...         ...         ...     ...       ...     ...      ...    ...
# 99995       1.0           0     2.0       1.0   160.0    118.0    2.0
# 99996       1.0           0     2.0       1.0  3787.0   1650.0   16.0
# 99997       1.0           0     2.0       1.0   921.0    217.0    3.0
# 99998       1.0           0     2.0       1.0   881.0    224.0    3.0
# 99999       NaN           1     NaN       NaN     NaN      NaN    NaN
#
#        bookmarks  comments                                        description  \
# 1            3.0       1.0  It requires a very unusual mind to undertake t...
# 2            6.0      73.0  A muttered insult takes on new meaning. Set du...
# 3            6.0      57.0  The breakup between Hiro and Ayaka leaves our ...
# 4           13.0      65.0  The breakup between Hiro and Ayaka leaves our ...
# 5           30.0      56.0  The things Aang and Zuko talk about when stuck...
# ...          ...       ...                                                ...
# 99995        0.0       2.0  Headlights cut/Through endless twilight/Eating...
# 99996        3.0       0.0  There came a point when it didn't matter anymo...
# 99997        1.0       2.0  Even when Mary died and left him with two smal...
# 99998        0.0       2.0         And he never thought once of stopping him.
# 99999        NaN       NaN                                                NaN
#
#       LanguageName         RatingName FinishedStatus
# 1          English        Teen And Up       Finished
# 2          English        Teen And Up       Finished
# 3          English             Mature       Finished
# 4          English             Mature       Finished
# 5          English  General Audiences       Finished
# ...            ...                ...            ...
# 99995      English             Mature       Finished
# 99996      English             Mature       Finished
# 99997      English             Mature       Finished
# 99998      English             Mature       Finished
# 99999          NaN                NaN            NaN
#
# [99999 rows x 17 columns]

# %%
# Task 1 - Analyzing the Correlation Between Different Measures of Popularity

col_keep = ["hits", "kudos", "comments", "bookmarks"]

corr_data = data.copy(deep= True)

for col in corr_data.columns:
    if col not in col_keep:
        corr_data.drop(columns=[col], inplace = True)
        
corr_data = corr_data.corr()

heatmap = plt.pcolor(corr_data, cmap=plt.cm.Blues, vmin = -1, vmax = 1)
ticks = [x for x in range(0, len(corr_data.columns))]
labels = [x for x in corr_data.columns]
plt.xticks(ticks = ticks, labels = labels, rotation = 90)
plt.yticks(ticks = ticks, labels = labels)
# plot the legend on the side
plt.colorbar(heatmap)

# %% [markdown]
# So we see that kudos and bookmarks have the highest correlation, and all four types of measures of engagement are positively correlated. Comments are not as correlated with the other three measures, and thus may not be needed in a linear regression model.

# %% [markdown]
# ### Question 2: What percentage of fanfic writers restrict access to their works?
# Find the total number of works. Find the total number of authors that restric access. Find percentage (restricted works/total works)

# %%
restricted = data.groupby('restricted').count()
print(restricted.head())
56545/(943454+56545)
# Out:
#             Unnamed: 0     id  title   date  language  rating  finished  \
# restricted
# 0                93803  93803  93715  93716     93716   93716     93716
# 1                 6196   6196      4      4         4       4         4
#
#             words   hits  kudos  bookmarks  comments  description  \
# restricted
# 0           93716  93716  93716      93716     93716        86791
# 1               4      4      4          4         4            4
#
#             LanguageName  RatingName  FinishedStatus
# restricted
# 0                  93716       93716           93716
# 1                      0           4               4
# 0.056545056545056545

# %% [markdown]
# There is a small portion of fanfic authors that restrict access to their book data. About 6% of authors at 100000 works.

# %%
# create data set without restricted data
useful_data = data[data['restricted']==0]
useful_data = useful_data[['title','date','language','restricted','rating','finished','words','hits','kudos','bookmarks','comments','description','LanguageName','RatingName','FinishedStatus']]
useful_data
# Out:
#                                       title        date  language  restricted  \
# 1                   Analysis of the Obvious  2008-09-13       1.0           0
# 2                 Dense Like Chocolate Cake  2008-09-13       1.0           0
# 3                                Dedication  2008-09-13       1.0           0
# 4                                Dedication  2008-09-13       1.0           0
# 5                 His Place In the Universe  2008-09-13       1.0           0
# ...                                     ...         ...       ...         ...
# 99993                          The Bells...  2007-09-17       1.0           0
# 99995                       Endless Road...  2006-08-19       1.0           0
# 99996                               Pain...  2006-11-18       1.0           0
# 99997   There, But for the Grace of Pt I...  2006-07-28       1.0           0
# 99998  There, But for the Grace of Pt II...  2006-10-02       1.0           0
#
#        rating  finished   words     hits  kudos  bookmarks  comments  \
# 1         1.0       1.0  2751.0   9643.0   43.0        3.0       1.0
# 2         1.0       1.0  4127.0  11831.0   24.0        6.0      73.0
# 3         2.0       1.0  5836.0  15812.0   25.0        6.0      57.0
# 4         2.0       1.0  5836.0   4803.0   51.0       13.0      65.0
# 5         0.0       1.0  1695.0  10520.0  202.0       30.0      56.0
# ...       ...       ...     ...      ...    ...        ...       ...
# 99993     2.0       1.0   469.0    160.0    7.0        0.0       0.0
# 99995     2.0       1.0   160.0    118.0    2.0        0.0       2.0
# 99996     2.0       1.0  3787.0   1650.0   16.0        3.0       0.0
# 99997     2.0       1.0   921.0    217.0    3.0        1.0       2.0
# 99998     2.0       1.0   881.0    224.0    3.0        0.0       2.0
#
#                                              description LanguageName  \
# 1      It requires a very unusual mind to undertake t...      English
# 2      A muttered insult takes on new meaning. Set du...      English
# 3      The breakup between Hiro and Ayaka leaves our ...      English
# 4      The breakup between Hiro and Ayaka leaves our ...      English
# 5      The things Aang and Zuko talk about when stuck...      English
# ...                                                  ...          ...
# 99993  It is the depths of midnight. Dean swears some...      English
# 99995  Headlights cut/Through endless twilight/Eating...      English
# 99996  There came a point when it didn't matter anymo...      English
# 99997  Even when Mary died and left him with two smal...      English
# 99998         And he never thought once of stopping him.      English
#
#               RatingName FinishedStatus
# 1            Teen And Up       Finished
# 2            Teen And Up       Finished
# 3                 Mature       Finished
# 4                 Mature       Finished
# 5      General Audiences       Finished
# ...                  ...            ...
# 99993             Mature       Finished
# 99995             Mature       Finished
# 99996             Mature       Finished
# 99997             Mature       Finished
# 99998             Mature       Finished
#
# [93803 rows x 15 columns]

# %% [markdown]
# ### Question 2: How many languages are found on AO3 and what percentage are they relative to all works?
# Group data by languages, find percentage of language in total works

# %%
lang = useful_data.groupby('LanguageName').count()
print(lang['language'])
print()
print('Number of unique languages in data set:',len(lang))
print()
print('Number of entries in data set:',len(useful_data))
print()

print(str(lang['language'].index),'makes up', str(lang['language']/len(useful_data))+'% of the total.')
print()
for i in range(len(lang['language'].index)):
    perc = round(lang['language'][i]/len(useful_data),3)*100
    if perc >= 0.1:
        print(lang['language'].index[i], 'makes up', str(perc) + '% of the total data.')
    else:
        print(lang['language'].index[i], 'makes up less than 0.1% of the total data.')
# Out:
# LanguageName
# Bahasa Indonesia           12
# Dansk                       2
# Deutsch                    91
# English                 93117
# Español                   221
# Esperanto                   3
# Français                   52
# Gàidhlig                    1
# Italiano                    6
# Lingua latina               2
# Magyar                      1
# Nederlands                 10
# Polski                     11
# Português brasileiro       62
# Suomi                       2
# Svenska                     7
# Tiếng Việt                  1
# Čeština                     8
# Русский                    77
# 中文                         30
# Name: language, dtype: int64
#
# Number of unique languages in data set: 20
#
# Number of entries in data set: 93803
#
# Index(['Bahasa Indonesia', 'Dansk', 'Deutsch', 'English', 'Español',
#        'Esperanto', 'Français', 'Gàidhlig', 'Italiano', 'Lingua latina',
#        'Magyar', 'Nederlands', 'Polski', 'Português brasileiro', 'Suomi',
#        'Svenska', 'Tiếng Việt', 'Čeština', 'Русский', '中文'],
#       dtype='object', name='LanguageName') makes up LanguageName
# Bahasa Indonesia        0.000128
# Dansk                   0.000021
# Deutsch                 0.000970
# English                 0.992687
# Español                 0.002356
# Esperanto               0.000032
# Français                0.000554
# Gàidhlig                0.000011
# Italiano                0.000064
# Lingua latina           0.000021
# Magyar                  0.000011
# Nederlands              0.000107
# Polski                  0.000117
# Português brasileiro    0.000661
# Suomi                   0.000021
# Svenska                 0.000075
# Tiếng Việt              0.000011
# Čeština                 0.000085
# Русский                 0.000821
# 中文                      0.000320
# Name: language, dtype: float64% of the total.
#
# Bahasa Indonesia makes up less than 0.1% of the total data.
# Dansk makes up less than 0.1% of the total data.
# Deutsch makes up 0.1% of the total data.
# English makes up 99.3% of the total data.
# Español makes up 0.2% of the total data.
# Esperanto makes up less than 0.1% of the total data.
# Français makes up 0.1% of the total data.
# Gàidhlig makes up less than 0.1% of the total data.
# Italiano makes up less than 0.1% of the total data.
# Lingua latina makes up less than 0.1% of the total data.
# Magyar makes up less than 0.1% of the total data.
# Nederlands makes up less than 0.1% of the total data.
# Polski makes up less than 0.1% of the total data.
# Português brasileiro makes up 0.1% of the total data.
# Suomi makes up less than 0.1% of the total data.
# Svenska makes up less than 0.1% of the total data.
# Tiếng Việt makes up less than 0.1% of the total data.
# Čeština makes up less than 0.1% of the total data.
# Русский makes up 0.1% of the total data.
# 中文 makes up less than 0.1% of the total data.

# %% [markdown]
# #### Optional
# ### Question 3: How do all useful data coorelate together?

# %%
# # create correlation matrix from data factors
# # establish data frame based on all current data except processDate,
# corr_matrix = useful_data.drop(['Unnamed: 0','processDate','title','restricted'],axis=1)
# # form correlation data from correlation data frame
# correlation = corr_matrix.corr()
# # create heat map
# heat_map = plt.pcolor(correlation,vmin=-1,vmax=1,cmap=plt.cm.coolwarm)
# plt.xticks(np.arange(0.5,len(correlation.index),1),correlation.index)
# plt.yticks(np.arange(0.5,len(correlation.columns),1),correlation.columns,rotation='vertical')
# plt.colorbar(heat_map)
