# %%
import pandas as pd

# %%
data = pd.read_csv('reduced_project_info.csv')
data
# Out:
#         Unnamed: 0          processDate  rating  finished  \
# 0                0                  NaN     NaN       NaN
# 1                1  2020-07-29 21:35:52     1.0       1.0
# 2                2  2020-07-29 21:38:01     1.0       1.0
# 3                3  2020-07-29 21:38:01     2.0       1.0
# 4                4  2020-07-29 21:38:01     2.0       1.0
# ...            ...                  ...     ...       ...
# 999995      999995  2020-07-30 00:13:46    -1.0       1.0
# 999996      999996  2020-07-30 00:02:11     1.0       1.0
# 999997      999997                  NaN     NaN       NaN
# 999998      999998  2020-07-30 00:15:37     1.0       1.0
# 999999      999999  2020-07-30 00:21:46    -1.0       1.0
#
#                                 title  language   words     hits  kudos  \
# 0                                 NaN       NaN     NaN      NaN    NaN
# 1             Analysis of the Obvious       1.0  2751.0   9643.0   43.0
# ...
